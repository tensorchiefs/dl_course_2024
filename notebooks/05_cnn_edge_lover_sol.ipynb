# %% [markdown]
# # A simple CNN for the edge lover task
#
# In this notebook you train a very simple CNN with only 1 kernel to distinguish between images containing vertical and images containing horizontal stripes. To check what pattern is recognized by the learned kernel you will visualize the weights of the kernel as an image. You will see that the CNN learns a useful kernel (either a vertical or horiziontal bar). You can experiment with the code to check the influence of the kernel size, the activation function and the pooling method on the result.
#
#
# **Dataset:** You work with an artficially generatet dataset of greyscale images (50x50 pixel) with 10 vertical or horizontal bars. We want to classify them into whether an art lover, who only loves vertical strips, will like the image (y = 0) or not like the image (y = 1).
#
# The idea of the notebook is that you try to understand the provided code by running it, checking the output and playing with it by slightly changing the code and rerunning it.
#
# **Content:**
# * definig and generating the dataset X_train and X_val
# * visualize samples of the generated images
# * use keras to train a CNN with only one kernel (5x5 pixel)
# * visualize the weights of the learned kernel and interpret if it is useful
# * repeat the last two steps to check if the learned kernel is always the same

# %% [markdown]
# ### Imports
#
# In the next cell, we load all the required libraries.

# %%
# load required libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten , Activation
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-02-27 10:22:20.116450: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-27 10:22:20.136143: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 10:22:20.136160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 10:22:20.136817: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-27 10:22:20.140648: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-27 10:22:20.499137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Defining functions to generate images
#
# Here we define the function to genere images with vertical and horizontal bars, the arguments of the functions are the size of the image and the number of bars you want to have. The bars are at random positions in the image with a random length. The image is black and white, meaning we have only two values for the pixels, 0 for black and 255 for white.

# %%
#define function to generate image with shape (size, size, 1) with stripes
def generate_image_with_bars(size, bar_nr, vertical = True):
    img = np.zeros((size,size,1), dtype="uint8")
    for i in range(0,bar_nr):
        x,y = np.random.randint(0,size,2)
        l  = int(np.random.randint(y,size,1)[0])
        if (vertical):
            img[y:l,x,0]=255
        else:
            img[x,y:l,0]=255
    return img

# %% [markdown]
# Let's have a look at the generated images. We choose a size of 50x50 pixels and set the number of bars in the image to 10.

# %%
# have a look on two generated images
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
img=generate_image_with_bars(50,10, vertical=True)
plt.imshow(img[:,:,0],cmap='gray')
plt.subplot(1,2,2)
img=generate_image_with_bars(50,10, vertical=False)
plt.imshow(img[:,:,0],cmap='gray')
plt.show()

# %% [markdown]
# ### Make a train and validation dataset of images with vertical and horizontal images
# Now, let's make a train dataset *X_train* with 1000 images (500 images with vertical and 500 images with horizontal bars). We normalize the images values to be between 0 and 1 by dividing all values with 255. We create a secont dataste *X_val* with exactly the same properties to validate the training of the CNN.

# %%
pixel=50  # define height and width of images
num_images_train = 1000 #Number of training examples (divisible by 2)
num_images_val = 1000 #Number of training examples (divisible by 2)

# generate training data with vertical edges
X_train =np.zeros((num_images_train,pixel,pixel,1))
for i in range(0, num_images_train//2):
    X_train[i]=generate_image_with_bars(pixel,10)
# ... with horizontal
for i in range(num_images_train//2, num_images_train):
    X_train[i]=generate_image_with_bars(pixel,10, vertical=False)

# generate validation data with vertical edges
X_val =np.zeros((num_images_train,pixel,pixel,1))
for i in range(0, num_images_train//2):
    X_val[i]=generate_image_with_bars(pixel,10)
# ... with horizontal
for i in range(num_images_train//2, num_images_train):
    X_val[i]=generate_image_with_bars(pixel,10, vertical=False)

# %%
# normalize the data to be between 0 and 1
X_train=X_train/255
X_val=X_val/255

print(X_train.shape)
print(X_val.shape)
# Out:
# (1000, 50, 50, 1)
# (1000, 50, 50, 1)

# %% [markdown]
# Here we make the labels for the art lover, 0 means he likes the image (vertical bars) and 1 means that he doesn't like it (horizontal stripes). We one hot encode the labels because we want to use two outputs in our network.

# %%
# create class labels
y = np.array([[0],[1]])
Y_train = np.repeat(y, num_images_train //2)
Y_val = np.repeat(y, num_images_train //2)

# one-hot-encoding
Y_train = to_categorical(Y_train,2)
Y_val = to_categorical(Y_val,2)

# %% [markdown]
# ## Defining the CNN
#
# Here we define the CNN:
#
# - we use only one kernel with a size of 5x5 pixels
# - then we apply a linar activation function
# - the maxpooling layer takes the maximum of the whole activation map to predict the probability (output layer with softmax) if the art lover will like the image
#
# As loss we use the categorical_crossentropy and we train the model with a batchsize of 64 images per update.

# %%
model = Sequential()

model.add(Convolution2D(1,(5,5),padding='same',input_shape=(pixel,pixel,1)))
model.add(Activation('linear'))

# take the max over all values in the activation map
model.add(MaxPooling2D(pool_size=(pixel,pixel)))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

# compile model and initialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# 2024-02-27 10:22:21.366401: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-27 10:22:21.385034: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# let's summarize the CNN architectures along with the number of model weights
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 1)         26
#
#  activation (Activation)     (None, 50, 50, 1)         0
#
#  max_pooling2d (MaxPooling2  (None, 1, 1, 1)           0
#  D)
#
#  flatten (Flatten)           (None, 1)                 0
#
#  dense (Dense)               (None, 2)                 4
#
#  activation_1 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 30 (120.00 Byte)
# Trainable params: 30 (120.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train the model
history=model.fit(X_train, Y_train,
                  validation_data=(X_val,Y_val),
                  batch_size=64,
                  epochs=150,
                  verbose=1)
# Out:
# Epoch 1/150
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6840 - accuracy: 0.5000 - val_loss: 0.6754 - val_accuracy: 0.5000
# Epoch 2/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6681 - accuracy: 0.5000 - val_loss: 0.6603 - val_accuracy: 0.5000
# Epoch 3/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6536 - accuracy: 0.5000 - val_loss: 0.6462 - val_accuracy: 0.5000
# Epoch 4/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6396 - accuracy: 0.5000 - val_loss: 0.6316 - val_accuracy: 0.5000
# Epoch 5/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6249 - accuracy: 0.5000 - val_loss: 0.6167 - val_accuracy: 0.5000
# Epoch 6/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6101 - accuracy: 0.5000 - val_loss: 0.6015 - val_accuracy: 0.5000
# Epoch 7/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5944 - accuracy: 0.5000 - val_loss: 0.5844 - val_accuracy: 0.5000
# Epoch 8/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5774 - accuracy: 0.5000 - val_loss: 0.5673 - val_accuracy: 0.5000
# Epoch 9/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.
150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 74/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 75/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 76/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 1.0000
# Epoch 77/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 78/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 79/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 80/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 81/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 82/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 83/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 84/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 85/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 86/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 87/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 88/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 89/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 90/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 91/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 92/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 93/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 94/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 95/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 96/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 97/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 98/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 1.0000
# Epoch 99/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 100/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 101/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 102/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 103/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 104/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 105/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 106/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 107/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 108/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 109/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 110/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 111/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 112/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 113/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 114/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 115/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 116/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 117/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 118/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 119/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 120/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 121/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 122/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 123/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 124/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 125/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 126/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 127/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 128/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 129/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 130/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 131/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 132/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 133/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 134/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 135/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 136/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 137/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 138/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 139/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 140/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 141/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 142/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 143/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 144/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 145/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 146/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 147/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 148/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 149/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 150/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000

# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %% [markdown]
# ### Visualize the learned kernel and experiment with the code
#
# You see that the CNN performs very good at this task (100% accuracy). We can check which pattern is recognized by the **learned kernel** and see if you think that this is helpful to distinguish between images with horizontal and vertical edges.
#
# Below you can see the original image, the image after the convolution operation with the learned kernel and the maximum value from the maxpooling operation. Note that the maxpooling has the same size as the convolved image so there is just one value as output.
#
#
# Move the sliders to inspect different pictures from the validation set and their predictions

# %%
## Do not worry about this cell, just move the sliders.
import scipy.signal
from skimage.measure import block_reduce  # For max pooling
import ipywidgets as widgets

plt.figure(figsize=(10, 3))
plt.subplot(1, 2, 1)
plt.imshow(np.random.rand(25).reshape(5, 5),"gray") ,plt.title('Randomly initalized weights')
plt.subplot(1, 2, 2)
conv_filter=np.squeeze(model.get_weights()[0], axis=2)
plt.imshow(conv_filter[:,:,0],"gray"),plt.title('Learned Kernel (weights) , by model'),plt.show();
print("\n---------Move the sliders to inspect different vertical and horizontal images from the valset and their predictions:------------------\n")

def scale_convolution_map(conv_map, min_val=-3, max_val=3):
    clipped_conv_map = np.clip(conv_map, min_val, max_val)
    scaled_conv_map = (clipped_conv_map - min_val) / (max_val - min_val)
    return scaled_conv_map

def plot_conv(img,category):
  convolved_image = scipy.signal.convolve2d(img.squeeze(), conv_filter.squeeze(), mode='same')
  scaled_conv_image = scale_convolution_map(convolved_image + model.get_weights()[1])
  max_pooled_image = block_reduce(convolved_image + model.get_weights()[1], block_size=(50, 50), func=np.max)
  scaled_max_pooled_image = scale_convolution_map(max_pooled_image)

  plt.figure(figsize=(20, 4))
  plt.subplot(1, 6, 1)
  plt.imshow(img, "gray", vmin=0, vmax=1),plt.title('Original Image')
  plt.subplot(1, 6, 2)
  plt.imshow(scaled_conv_image, "gray", vmin=0, vmax=1),plt.title('Convolved Image')
  plt.subplot(1, 6, 3),plt.imshow(scaled_max_pooled_image, "gray", vmin=0, vmax=1)
  plt.title(f'Max Pooled = {max_pooled_image[0][0]:.2f}'),plt.xticks([]), plt.yticks([])
  plt.subplot(1, 6, 4),plt.axis('off')
  pred = model.predict(img.reshape(1, 50, 50, 1), verbose=0)
  if category=="vertical":
    text_info = f'''
    P(y=vertical|x): {pred[0][0]:.4f}
    P(y=horizontal|x): {pred[0][1]:.4f}


    loss component:  {-np.log(pred[0][0]):.4f}
      '''
  else:
        text_info = f'''
    P(y=vertical|x): {pred[0][0]:.4f}
    P(y=horizontal|x): {pred[0][1]:.4f}


    loss component:  {-np.log(pred[0][1]):.4f}
      '''

  plt.text(0, 0.5, text_info, ha='left', va='center')
  plt.subplot(1, 6, 5)
  x_values = np.linspace(0.001, 1.1, 500)
  plt.plot(x_values, -np.log(x_values), label='-log(P(y|x))')
  plt.ylim(-0.5, 6),plt.xlim(-0.1, 1.1),plt.xlabel('P(y|x)')
  if category=="vertical":
    plt.plot(pred[0][0], -np.log(pred[0][0]), 'bo', label='loss component')
  else:
    plt.plot(pred[0][1], -np.log(pred[0][1]), 'ro', label='loss component')

  plt.legend(),plt.grid(True), plt.tight_layout(),plt.show()

def inspect_preds(idx,category='vertical'):
  plot_conv(X_val[idx,:,:,0],category)
# Out:
# ---------Move the sliders to inspect different vertical and horizontal images from the valset and their predictions:------------------

# %%
horizontal_slider = widgets.IntSlider(min=0, max=num_images_val//2-1, step=1, value=0, description='vertical')
widgets.interact(inspect_preds, idx=horizontal_slider,category=widgets.fixed('vertical'));
# Out:
# interactive(children=(IntSlider(value=0, description='vertical', max=499), Output()), _dom_classes=('widget-in…

# %%
vertical_slider = widgets.IntSlider(min=num_images_val//2, max=num_images_val-1, step=1, value=0, description='horizontal')
widgets.interact(inspect_preds, idx=vertical_slider,category=widgets.fixed('horizontal'));
# Out:
# interactive(children=(IntSlider(value=500, description='horizontal', max=999, min=500), Output()), _dom_classe…

# %% [markdown]
# ## Excercise 1
#
# Given the probabilities, please calculate the loss component for one example of the validation set.

# %% [markdown]
# assumed that we have a vertical image,  label = vertical or translated to numbers label = 0
#
# assume that probabilites by the model for said example are:
#
#  $p_{model}(y=0|image
# ) = 0.9$
#
#
# The NLL for a sample is given by: $ l_{i}= -log(p_{model}(y_{i}|x_{i})) $
#
# The loss: $loss = \frac{1}{N} \sum_{}{} li$
#
#
#
# $ = - \left[ \log(0.9) \right]$
#
# $ =  0.1053 $

# %% [markdown]
# ## Excercise 2
#
#
# - Repeat the compiling and training, beginning from the cell:
#
# ```
# model = Sequential()
#
#        ...
#
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])
# ```
#
# for several times and check if the CNN always learns the same kernel.
#
# ## Additional Excercise
#
# - You can experiment with the code and check what happens if you use another kernel size, activation function (relu instead of linear ) or pooling method AveragePooling instead of MaxPooling.  Try to make a prediction on the performance before doing the experiment.

# %% [markdown]
# ## Answer 2:
#
# - No it does not, sometimes it learns the horizontal patterns, and sometimes the vertical pattern.

# %%
model = Sequential()

model.add(Convolution2D(1,(5,5),padding='same',input_shape=(pixel,pixel,1)))
model.add(Activation('relu'))

# take the max over all values in the activation map
model.add(MaxPooling2D(pool_size=(pixel,pixel)))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

# compile model and initialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# train the model
history=model.fit(X_train, Y_train,
                  validation_data=(X_val,Y_val),
                  batch_size=64,
                  epochs=150,
                  verbose=1)

# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
# Out:
# Epoch 1/150
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.5000 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 2/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6890 - val_accuracy: 0.5000
# Epoch 4/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5000 - val_loss: 0.6843 - val_accuracy: 0.5000
# Epoch 5/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.5000 - val_loss: 0.6774 - val_accuracy: 0.5000
# Epoch 6/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.5000 - val_loss: 0.6683 - val_accuracy: 0.5000
# Epoch 7/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.5000 - val_loss: 0.6568 - val_accuracy: 0.5000
# Epoch 8/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6492 - accuracy: 0.5000 - val_loss: 0.6429 - val_accuracy: 0.5000
# Epoch 9/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6341 - accuracy: 0.5000 - val_loss: 0.6274 - val_accuracy: 0.5000
# Epoch 10/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6176 - accuracy: 0.5000 - val_loss: 0.6109 - val_accuracy: 0.5000
# Epoch 11/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.5000 - val_loss: 0.5926 - val_accuracy: 0.5000
# Epoch 12/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5812 - accuracy: 0.6710 - val_loss: 0.5730 - val_accuracy: 0.8330
# Epoch 13/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.8490 - val_loss: 0.5524 - val_accuracy: 0.8620
# Epoch 14/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.8700 - val_loss: 0.5317 - val_accuracy: 0.8960
# Epoch 15/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.9120 - val_loss: 0.5109 - val_accuracy: 0.9000
# Epoch 16/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.9160 - val_loss: 0.4894 - val_accuracy: 0.9060
# Epoch 17/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.9320 - val_loss: 0.4681 - val_accuracy: 0.9270
# Epoch 18/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.9490 - val_loss: 0.4466 - val_accuracy: 0.9510
# Epoch 19/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4347 - accuracy: 0.9910 - val_loss: 0.4256 - val_accuracy: 0.9960
# Epoch 20/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4140 - accuracy: 0.9940 - val_loss: 0.4050 - val_accuracy: 0.9970
# Epoch 21/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.9970 - val_loss: 0.3852 - val_accuracy: 0.9980
# Epoch 22/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.9990 - val_loss: 0.3670 - val_accuracy: 0.9980
# Epoch 23/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3581 - accuracy: 0.9990 - val_loss: 0.3508 - val_accuracy: 0.9980
# Epoch 24/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.9990 - val_loss: 0.3358 - val_accuracy: 0.9980
# Epoch 25/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.9990 - val_loss: 0.3215 - val_accuracy: 0.9990
# Epoch 26/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.
150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 59/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 60/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 61/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 62/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 63/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 64/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 65/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 1.0000
# Epoch 66/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 1.0000
# Epoch 67/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 68/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0842 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 69/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 70/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 71/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 72/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 73/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 74/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 75/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 76/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 77/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 78/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 79/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 1.0000
# Epoch 80/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 81/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 1.0000
# Epoch 82/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 1.0000
# Epoch 83/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 84/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 85/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 86/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 87/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 88/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 1.0000
# Epoch 89/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 90/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 91/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 1.0000
# Epoch 92/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 93/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 94/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 95/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 96/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 97/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 98/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 99/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 1.0000
# Epoch 100/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 101/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 102/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 103/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 104/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 105/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 106/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 107/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 108/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 109/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 110/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 111/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 112/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 113/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 114/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 115/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 116/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 117/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 1.0000
# Epoch 118/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 119/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 120/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 121/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 122/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 123/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 124/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 125/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 126/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 127/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 128/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 1.0000
# Epoch 129/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 130/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 131/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 132/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 133/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 1.0000
# Epoch 134/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 135/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 136/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 137/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 138/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 139/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 140/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 141/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 142/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 143/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 144/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 1.0000
# Epoch 145/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 146/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 147/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 148/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 149/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 150/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000
