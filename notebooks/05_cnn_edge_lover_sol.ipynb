# %% [markdown]
# # A simple CNN for the edge lover task
#
# In this notebook you train a very simple CNN with only 1 kernel to distinguish between images containing vertical and images containing horizontal stripes. To check what pattern is recognized by the learned kernel you will visualize the weights of the kernel as an image. You will see that the CNN learns a useful kernel (either a vertical or horiziontal bar). You can experiment with the code to check the influence of the kernel size, the activation function and the pooling method on the result.
#
#
# **Dataset:** You work with an artficially generatet dataset of greyscale images (50x50 pixel) with 10 vertical or horizontal bars. We want to classify them into whether an art lover, who only loves vertical strips, will like the image (y = 0) or not like the image (y = 1).
#
# The idea of the notebook is that you try to understand the provided code by running it, checking the output and playing with it by slightly changing the code and rerunning it.
#
# **Content:**
# * definig and generating the dataset X_train and X_val
# * visualize samples of the generated images
# * use keras to train a CNN with only one kernel (5x5 pixel)
# * visualize the weights of the learned kernel and interpret if it is useful
# * repeat the last two steps to check if the learned kernel is always the same

# %% [markdown]
# ### Imports
#
# In the next cell, we load all the required libraries.

# %%
# load required libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten , Activation
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Defining functions to generate images
#
# Here we define the function to genere images with vertical and horizontal bars, the arguments of the functions are the size of the image and the number of bars you want to have. The bars are at random positions in the image with a random length. The image is black and white, meaning we have only two values for the pixels, 0 for black and 255 for white.

# %%
#define function to generate image with shape (size, size, 1) with stripes
def generate_image_with_bars(size, bar_nr, vertical = True):
    img = np.zeros((size,size,1), dtype="uint8")
    for i in range(0,bar_nr):
        x,y = np.random.randint(0,size,2)
        l  = int(np.random.randint(y,size,1)[0])
        if (vertical):
            img[y:l,x,0]=255
        else:
            img[x,y:l,0]=255
    return img

# %% [markdown]
# Let's have a look at the generated images. We choose a size of 50x50 pixels and set the number of bars in the image to 10.

# %%
# have a look on two generated images
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
img=generate_image_with_bars(50,10, vertical=True)
plt.imshow(img[:,:,0],cmap='gray')
plt.subplot(1,2,2)
img=generate_image_with_bars(50,10, vertical=False)
plt.imshow(img[:,:,0],cmap='gray')
plt.show()

# %% [markdown]
# ### Make a train and validation dataset of images with vertical and horizontal images
# Now, let's make a train dataset *X_train* with 1000 images (500 images with vertical and 500 images with horizontal bars). We normalize the images values to be between 0 and 1 by dividing all values with 255. We create a secont dataste *X_val* with exactly the same properties to validate the training of the CNN.

# %%
pixel=50  # define height and width of images
num_images_train = 1000 #Number of training examples (divisible by 2)
num_images_val = 1000 #Number of training examples (divisible by 2)

# generate training data with vertical edges
X_train =np.zeros((num_images_train,pixel,pixel,1))
for i in range(0, num_images_train//2):
    X_train[i]=generate_image_with_bars(pixel,10)
# ... with horizontal
for i in range(num_images_train//2, num_images_train):
    X_train[i]=generate_image_with_bars(pixel,10, vertical=False)

# generate validation data with vertical edges
X_val =np.zeros((num_images_train,pixel,pixel,1))
for i in range(0, num_images_train//2):
    X_val[i]=generate_image_with_bars(pixel,10)
# ... with horizontal
for i in range(num_images_train//2, num_images_train):
    X_val[i]=generate_image_with_bars(pixel,10, vertical=False)

# %%
# normalize the data to be between 0 and 1
X_train=X_train/255
X_val=X_val/255

print(X_train.shape)
print(X_val.shape)
# Out:
# (1000, 50, 50, 1)
# (1000, 50, 50, 1)

# %% [markdown]
# Here we make the labels for the art lover, 0 means he likes the image (vertical bars) and 1 means that he doesn't like it (horizontal stripes). We one hot encode the labels because we want to use two outputs in our network.

# %%
# create class labels
y = np.array([[0],[1]])
Y_train = np.repeat(y, num_images_train //2)
Y_val = np.repeat(y, num_images_train //2)

# one-hot-encoding
Y_train = to_categorical(Y_train,2)
Y_val = to_categorical(Y_val,2)

# %% [markdown]
# ## Defining the CNN
#
# Here we define the CNN:
#
# - we use only one kernel with a size of 5x5 pixels
# - then we apply a linar activation function
# - the maxpooling layer takes the maximum of the whole activation map to predict the probability (output layer with softmax) if the art lover will like the image
#
# As loss we use the categorical_crossentropy and we train the model with a batchsize of 64 images per update.

# %%
model = Sequential()

model.add(Convolution2D(1,(5,5),padding='same',input_shape=(pixel,pixel,1)))
model.add(Activation('linear'))

# take the max over all values in the activation map
model.add(MaxPooling2D(pool_size=(pixel,pixel)))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

# compile model and initialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# let's summarize the CNN architectures along with the number of model weights
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 50, 50, 1)         26
#
#  activation_4 (Activation)   (None, 50, 50, 1)         0
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 1)           0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1)                 0
#
#  dense_2 (Dense)             (None, 2)                 4
#
#  activation_5 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 30 (120.00 Byte)
# Trainable params: 30 (120.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train the model
history=model.fit(X_train, Y_train,
                  validation_data=(X_val,Y_val),
                  batch_size=64,
                  epochs=40,
                  verbose=1)
# Out:
# Epoch 1/40
# 16/16 [==============================] - 2s 82ms/step - loss: 0.6896 - accuracy: 0.5000 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 2/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6844 - accuracy: 0.5000 - val_loss: 0.6804 - val_accuracy: 0.5000
# Epoch 3/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.6783 - accuracy: 0.5000 - val_loss: 0.6732 - val_accuracy: 0.5000
# Epoch 4/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6702 - accuracy: 0.5000 - val_loss: 0.6638 - val_accuracy: 0.5000
# Epoch 5/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6602 - accuracy: 0.5000 - val_loss: 0.6523 - val_accuracy: 0.5000
# Epoch 6/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6478 - accuracy: 0.5000 - val_loss: 0.6390 - val_accuracy: 0.5000
# Epoch 7/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6339 - accuracy: 0.5000 - val_loss: 0.6241 - val_accuracy: 0.5000
# Epoch 8/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6184 - accuracy: 0.5500 - val_loss: 0.6077 - val_accuracy: 0.6540
# Epoch 9/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6017 - accuracy: 0.6640 - val_loss: 0.5902 - val_accuracy: 0.7180
# Epoch 10/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.5841 - accuracy: 0.7180 - val_loss: 0.5722 - val_accuracy: 0.7500
# Epoch 11/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.5659 - accuracy: 0.7710 - val_loss: 0.5537 - val_accuracy: 0.8000
# Epoch 12/40
# 16/16 [==============================] - 1s 84ms/step - loss: 0.5477 - accuracy: 0.8080 - val_loss: 0.5350 - val_accuracy: 0.8270
# Epoch 13/40
# 16/16 [==============================] - 1s 67ms/step - loss: 0.5294 - accuracy: 0.8350 - val_loss: 0.5167 - val_accuracy: 0.8480
# Epoch 14/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.5112 - accuracy: 0.8720 - val_loss: 0.4984 - val_accuracy: 0.8810
# Epoch 15/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.4933 - accuracy: 0.8960 - val_loss: 0.4804 - val_accuracy: 0.9090
# Epoch 16/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.4756 - accuracy: 0.9260 - val_loss: 0.4629 - val_accuracy: 0.9410
# Epoch 17/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.4583 - accuracy: 0.9490 - val_loss: 0.4457 - val_accuracy: 0.9500
# Epoch 18/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.4413 - accuracy: 0.9670 - val_loss: 0.4289 - val_accuracy: 0.9670
# Epoch 19/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.4247 - accuracy: 0.9860 - val_loss: 0.4126 - val_accuracy: 0.9890
# Epoch 20/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.4085 - accuracy: 0.9940 - val_loss: 0.3967 - val_accuracy: 0.9990
# Epoch 21/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3927 - accuracy: 1.0000 - val_loss: 0.3812 - val_accuracy: 0.9990
# Epoch 22/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3772 - accuracy: 1.0000 - val_loss: 0.3661 - val_accuracy: 0.9990
# Epoch 23/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3619 - accuracy: 1.0000 - val_loss: 0.3514 - val_accuracy: 0.9990
# Epoch 24/40
# 16/16 [==============================] - 1s 83ms/step - loss: 0.3473 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9990
# Epoch 25/40
# 16/16 [==============================] - 1s 68ms/step - loss: 0.3332 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9990
# Epoch 26/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.3197 - accuracy: 1.0000 - val_loss: 0.3107 - val_accuracy: 0.9990
# Epoch 27/40
# 16/16 [==============================] - 1s 59ms/step - loss: 0.3066 - accuracy: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9990
# Epoch 28/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2939 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9990
# Epoch 29/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.2820 - accuracy: 1.0000 - val_loss: 0.2746 - val_accuracy: 0.9990
# Epoch 30/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2707 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9990
# Epoch 31/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2600 - accuracy: 1.0000 - val_loss: 0.2535 - val_accuracy: 0.9990
# Epoch 32/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2496 - accuracy: 1.0000 - val_loss: 0.2436 - val_accuracy: 0.9990
# Epoch 33/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2397 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9990
# Epoch 34/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2303 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9990
# Epoch 35/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2213 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9990
# Epoch 36/40
# 16/16 [==============================] - 1s 81ms/step - loss: 0.2126 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9990
# Epoch 37/40
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2043 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9990
# Epoch 38/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1963 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9990
# Epoch 39/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.1887 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9990
# Epoch 40/40
# 16/16 [==============================] - 1s 59ms/step - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9990

# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %% [markdown]
# ### Visualize the learned kernel and experiment with the code
#
# You see that the CNN performs very good at this task (100% accuracy). We can check which pattern is recognized by the **learned kernel** and see if you think that this is helpful to distinguish between images with horizontal and vertical edges.
#
# Below you can see the original image, the image after the convolution operation with the learned kernel and the maximum value from the maxpooling operation. Note that the maxpooling has the same size as the convolved image so there is just one value as output.
#
# Move the sliders to inspect different pictures from the validation set and their predictions

# %%
## Do not worry about this cell, just move the sliders.
import scipy.signal
from skimage.measure import block_reduce  # For max pooling
import ipywidgets as widgets

# Kernel from model
plt.figure(figsize=(10, 3))
plt.subplot(1, 2, 1)
plt.imshow(np.random.rand(25).reshape(5, 5),"gray") ,plt.title('Randomly initalized weights')
plt.subplot(1, 2, 2)
conv_filter=np.squeeze(model.get_weights()[0], axis=2)
plt.imshow(conv_filter[:,:,0],"gray"),plt.title('Learned Kernel (weights) , by model'),plt.show();
print("\n---------Move the sliders to inspect different vertical and horizontal images from the valset and their predictions:------------------\n")

def scale_convolution_map(conv_map, min_val=-3, max_val=3):
    clipped_conv_map = np.clip(conv_map, min_val, max_val)
    scaled_conv_map = (clipped_conv_map - min_val) / (max_val - min_val)
    return scaled_conv_map

def plot_conv(img):
  convolved_image = scipy.signal.convolve2d(img.squeeze(), conv_filter.squeeze(), mode='same')
  scaled_conv_image = scale_convolution_map(convolved_image+model.get_weights()[1])
  max_pooled_image = block_reduce(convolved_image+model.get_weights()[1], block_size=(50, 50), func=np.max)
  scaled_max_pooled_image = scale_convolution_map(max_pooled_image)
  plt.figure(figsize=(10, 3))
  plt.subplot(1, 4, 1), plt.imshow(img,"gray", vmin=0, vmax=1),plt.title(f'Original Image')
  plt.subplot(1, 4, 2),plt.imshow(scaled_conv_image,"gray", vmin=0, vmax=1),plt.title('Convolved Image')
  plt.subplot(1, 4, 3)
  plt.imshow(scaled_max_pooled_image, "gray",vmin=0, vmax=1),plt.title(f'Max Pooled (just 1 value here)  = {max_pooled_image[0][0]:.2f} ',fontsize=8)
  plt.xticks([]),plt.yticks([])
  plt.subplot(1, 4, 4)
  pred=model.predict(img.reshape(1, 50, 50, 1),verbose=0)
  plt.text(0.5, 0.6, f'P(y=vertical|x):  {pred[0][0]:.4f}')
  plt.text(0.5, 0.4, f'P(y=horizontal|x): {pred[0][1]:.4f}')
  plt.axis('off'),plt.show();

def inspect_preds(horizontal,vertical):
  plot_conv(X_val[horizontal,:,:,0])
  plot_conv(X_val[vertical,:,:,0])

horizontal_slider = widgets.IntSlider(min=0, max=num_images_val//2-1, step=1, value=0, description='vertical ')
vertical_slider = widgets.IntSlider(min=num_images_val//2, max=num_images_val-1, step=1, value=0, description='horizontal')
widgets.interact(inspect_preds, horizontal=horizontal_slider, vertical=vertical_slider);
# Out:
# ---------Move the sliders to inspect different vertical and horizontal images from the valset and their predictions:------------------
# interactive(children=(IntSlider(value=0, description='vertical ', max=499), IntSlider(value=500, description='…

# %% [markdown]
# ### Repeat the training and experiment with the kernelsize and activation function.
#
# **Exercise**:
# - Repeat the compiling and training, beginning from the cell:
#
# ```
# model = Sequential()
#
#        ...
#
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])
# ```
#
# for several times and check if the CNN always learns the same kernel.
#
# - You can experiment with the code and check what happens if you use another kernel size, activation function (relu instead of linear ) or pooling method AveragePooling instead of MaxPooling.  Try to make a prediction on the performance before doing the experiment.

# %% [markdown]
# ## Answer:
#
# - No it does not, sometimes it learns the horizontal patterns, and sometimes the vertical pattern.
#
# -

# %%
model = Sequential()

model.add(Convolution2D(1,(5,5),padding='same',input_shape=(pixel,pixel,1)))
model.add(Activation('relu'))

# take the max over all values in the activation map
model.add(MaxPooling2D(pool_size=(pixel,pixel)))
model.add(Flatten())
model.add(Dense(2))
model.add(Activation('softmax'))

# compile model and initialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# train the model
history=model.fit(X_train, Y_train,
                  validation_data=(X_val,Y_val),
                  batch_size=64,
                  epochs=40,
                  verbose=1)

# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
# Out:
# Epoch 1/40
# 16/16 [==============================] - 1s 66ms/step - loss: 0.6991 - accuracy: 0.5000 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 2/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6954 - accuracy: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.5000
# Epoch 3/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 4/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6923 - accuracy: 0.5000 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 5/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6911 - accuracy: 0.5000 - val_loss: 0.6898 - val_accuracy: 0.5000
# Epoch 6/40
# 16/16 [==============================] - 1s 93ms/step - loss: 0.6888 - accuracy: 0.5000 - val_loss: 0.6864 - val_accuracy: 0.5000
# Epoch 7/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6843 - accuracy: 0.5000 - val_loss: 0.6800 - val_accuracy: 0.5000
# Epoch 8/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6762 - accuracy: 0.5000 - val_loss: 0.6691 - val_accuracy: 0.5000
# Epoch 9/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6633 - accuracy: 0.5000 - val_loss: 0.6537 - val_accuracy: 0.5000
# Epoch 10/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6465 - accuracy: 0.5110 - val_loss: 0.6347 - val_accuracy: 0.5120
# Epoch 11/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6272 - accuracy: 0.5200 - val_loss: 0.6136 - val_accuracy: 0.5230
# Epoch 12/40
# 16/16 [==============================] - 1s 59ms/step - loss: 0.6053 - accuracy: 0.5890 - val_loss: 0.5911 - val_accuracy: 0.6250
# Epoch 13/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.5823 - accuracy: 0.7250 - val_loss: 0.5675 - val_accuracy: 0.8430
# Epoch 14/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.5586 - accuracy: 0.8850 - val_loss: 0.5432 - val_accuracy: 0.9080
# Epoch 15/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.5347 - accuracy: 0.9310 - val_loss: 0.5190 - val_accuracy: 0.9630
# Epoch 16/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.5105 - accuracy: 0.9680 - val_loss: 0.4953 - val_accuracy: 0.9780
# Epoch 17/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.4868 - accuracy: 0.9820 - val_loss: 0.4719 - val_accuracy: 0.9910
# Epoch 18/40
# 16/16 [==============================] - 1s 93ms/step - loss: 0.4635 - accuracy: 0.9950 - val_loss: 0.4492 - val_accuracy: 0.9970
# Epoch 19/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.4409 - accuracy: 0.9980 - val_loss: 0.4272 - val_accuracy: 1.0000
# Epoch 20/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.4191 - accuracy: 0.9990 - val_loss: 0.4061 - val_accuracy: 1.0000
# Epoch 21/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3984 - accuracy: 0.9990 - val_loss: 0.3865 - val_accuracy: 1.0000
# Epoch 22/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3792 - accuracy: 1.0000 - val_loss: 0.3681 - val_accuracy: 1.0000
# Epoch 23/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3611 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 1.0000
# Epoch 24/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3441 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 1.0000
# Epoch 25/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.3283 - accuracy: 1.0000 - val_loss: 0.3194 - val_accuracy: 1.0000
# Epoch 26/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.3138 - accuracy: 1.0000 - val_loss: 0.3055 - val_accuracy: 1.0000
# Epoch 27/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.3003 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 1.0000
# Epoch 28/40
# 16/16 [==============================] - 1s 60ms/step - loss: 0.2876 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 1.0000
# Epoch 29/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.2757 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 1.0000
# Epoch 30/40
# 16/16 [==============================] - 1s 94ms/step - loss: 0.2646 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 1.0000
# Epoch 31/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2541 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 1.0000
# Epoch 32/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2441 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 1.0000
# Epoch 33/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2348 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 1.0000
# Epoch 34/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2259 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 1.0000
# Epoch 35/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2175 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 1.0000
# Epoch 36/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.2096 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 1.0000
# Epoch 37/40
# 16/16 [==============================] - 1s 56ms/step - loss: 0.2021 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 1.0000
# Epoch 38/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.1950 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 1.0000
# Epoch 39/40
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1884 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 1.0000
# Epoch 40/40
# 16/16 [==============================] - 1s 57ms/step - loss: 0.1820 - accuracy: 1.0000 - val_loss: 0.1776 - val_accuracy: 1.0000
